# %% [markdown]
# # Worksheet 02
#
# Name: Emmalee Gomez
# UID: U76797176
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# Top-down design are less adaptable to changes in requirements. Once a high-level design is established, making changes affects every function below.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# Without a clear high-level design, developers may unknowingly duplicate efforts, implementing similar functionality in different parts of the codebase.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# 1. Read the error: what it's telling you, where it occured, is that location the root cause?
# 2. Re-read the code: Mentally trace through the code to reproduce the error in head.
# 3. Take breaks.

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
class Board:
    BOARD_SIZE = 8

    def __init__(self):
        self.board = [["_" for _ in range(self.BOARD_SIZE)] for _ in range(self.BOARD_SIZE)]
        self.num_solutions = 0


    def __repr__(self) -> str:
        res = ""
        for row in self.board:
            for col in row:
                res += col + " "
            res += "\n"
        return res

    def is_row_legal(self, row):
        for j in range(len(self.board[row])):
            if self.is_queen_at(row, j):
                return False
        return True
    
    def is_col_legal(self, col):
        for i in range(len(self.board)):
            if self.is_queen_at(i, col):
                return False
        return True

    def is_diagonal_legal(self, row, col):
        for i in range(len(self.board)):
            for j in range(len(self.board[i])):
                if self.is_queen_at(i, j):
                    if abs(row - i) == abs(col - j):
                        return False
        return True

    def is_legal(self, row, col):
        if not self.is_row_legal(row):
            return False
        if not self.is_col_legal(col):
            return False
        if not self.is_diagonal_legal(row, col):
            return False
        return True
    
    def is_queen_at(self, row, col):
        return self.board[row][col] == "Q"
    
    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"
    
    def unset_queen_at(self, row):
        self.board[row] = ["_" for _ in range(self.BOARD_SIZE)]

    def is_on_board(self, row, col):
        return row >= 0 and row < self.BOARD_SIZE and col >= 0 and col < self.BOARD_SIZE

    def prof_is_legal_diag(self, row, col):
        for i in range(len(self.board)):
            if self.is_on_board(row - 1, col - 1) and self.is_queen_at(row - 1, col - 1):
                return False
            if self.is_on_board(row - 1, col + 1) and self.is_queen_at(row - 1, col + 1):
                return False
            if self.is_on_board(row + 1, col - 1) and self.is_queen_at(row + 1, col - 1):
                return False
            if self.is_on_board(row + 1, col + 1) and self.is_queen_at(row + 1, col + 1):
                return False
        return True

    def get_queen_on(self, row):
        for col in range(len(self.board[row])):
            if self.is_queen_at(row, col):
                return col
        raise ValueError("No queen on row {}, likely programmer error.".format(row))

    def search(self):
        row = 0
        col = 0
        while row >= 0:
            if row < self.BOARD_SIZE:
                if self.is_legal(row, col):
                    self.set_queen_at(row, col)
                    row += 1
                    col = 0
                else:
                    col += 1
                    while col >= self.BOARD_SIZE:
                        if row == 0:
                            return                        
                        col = self.get_queen_on(row-1)
                        self.unset_queen_at(row-1)
                        col += 1
                        row -= 1


            else:
                print("found solution")
                print(self)
                self.num_solutions += 1
                col = self.get_queen_on(row-1)
                self.unset_queen_at(row-1)
                col += 1
                row -= 1
                if row == 0:
                    return
                elif col >= self.BOARD_SIZE:
                    col = self.get_queen_on(row-1)
                    self.unset_queen_at(row-1)
                    col += 1
                    row -= 1
                    if row == 0:
                        return

                

my_board = Board()
my_board.search()
print("number of solutions: ", my_board.num_solutions)
# Out:
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# found solution
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# found solution
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# found solution
# ...
